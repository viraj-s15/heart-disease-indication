# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score
filename = "../data/processed/heart_disease_processed.csv"
df = pd.read_csv(filename)
df.head()
# Out:
#    Unnamed: 0    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0           0  16.60        1                0       0             3.0
# 1           1  20.34        0                0       1             0.0
# 2           2  26.58        1                0       0            20.0
# 3           3  24.21        0                0       0             0.0
# 4           4  23.71        0                0       0            28.0
#
#    MentalHealth  DiffWalking  Sex  Race  Diabetic  PhysicalActivity  \
# 0          30.0            0    0     5         2                 1
# 1           0.0            0    0     5         0                 1
# 2          30.0            0    1     5         2                 1
# 3           0.0            0    0     5         0                 0
# 4           0.0            1    0     5         0                 1
#
#    GenHealth  SleepTime  Asthma  KidneyDisease  SkinCancer  Outcome  Age
# 0          4        5.0       1              0           1        0   57
# 1          4        7.0       0              0           0        0   89
# 2          1        8.0       1              0           0        0   67
# 3          2        6.0       0              0           1        0   77
# 4          4        8.0       0              0           0        0   42

# %%
df = df.drop("Unnamed: 0", axis=1)

# %%
df.head()
# Out:
#      BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  MentalHealth  \
# 0  16.60        1                0       0             3.0          30.0
# 1  20.34        0                0       1             0.0           0.0
# 2  26.58        1                0       0            20.0          30.0
# 3  24.21        0                0       0             0.0           0.0
# 4  23.71        0                0       0            28.0           0.0
#
#    DiffWalking  Sex  Race  Diabetic  PhysicalActivity  GenHealth  SleepTime  \
# 0            0    0     5         2                 1          4        5.0
# 1            0    0     5         0                 1          4        7.0
# 2            0    1     5         2                 1          1        8.0
# 3            0    0     5         0                 0          2        6.0
# 4            1    0     5         0                 1          4        8.0
#
#    Asthma  KidneyDisease  SkinCancer  Outcome  Age
# 0       1              0           1        0   57
# 1       0              0           0        0   89
# 2       1              0           0        0   67
# 3       0              0           1        0   77
# 4       0              0           0        0   42

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   BMI               319795 non-null  float64
#  1   Smoking           319795 non-null  int64
#  2   AlcoholDrinking   319795 non-null  int64
#  3   Stroke            319795 non-null  int64
#  4   PhysicalHealth    319795 non-null  float64
#  5   MentalHealth      319795 non-null  float64
#  6   DiffWalking       319795 non-null  int64
#  7   Sex               319795 non-null  int64
#  8   Race              319795 non-null  int64
#  9   Diabetic          319795 non-null  int64
#  10  PhysicalActivity  319795 non-null  int64
#  11  GenHealth         319795 non-null  int64
#  12  SleepTime         319795 non-null  float64
#  13  Asthma            319795 non-null  int64
#  14  KidneyDisease     319795 non-null  int64
#  15  SkinCancer        319795 non-null  int64
#  16  Outcome           319795 non-null  int64
#  17  Age               319795 non-null  int64
# dtypes: float64(4), int64(14)
# memory usage: 43.9 MB

# %%
df.describe()
# Out:
#                  BMI        Smoking  AlcoholDrinking         Stroke  \
# count  319795.000000  319795.000000    319795.000000  319795.000000
# mean       28.325399       0.412477         0.068097       0.037740
# std         6.356100       0.492281         0.251912       0.190567
# min        12.020000       0.000000         0.000000       0.000000
# 25%        24.030000       0.000000         0.000000       0.000000
# 50%        27.340000       0.000000         0.000000       0.000000
# 75%        31.420000       1.000000         0.000000       0.000000
# max        94.850000       1.000000         1.000000       1.000000
#
#        PhysicalHealth   MentalHealth    DiffWalking            Sex  \
# count    319795.00000  319795.000000  319795.000000  319795.000000
# mean          3.37171       3.898366       0.138870       0.475273
# std           7.95085       7.955235       0.345812       0.499389
# min           0.00000       0.000000       0.000000       0.000000
# 25%           0.00000       0.000000       0.000000       0.000000
# 50%           0.00000       0.000000       0.000000       0.000000
# 75%           2.00000       3.000000       0.000000       1.000000
# max          30.00000      30.000000       1.000000       1.000000
#
#                 Race       Diabetic  PhysicalActivity      GenHealth  \
# count  319795.000000  319795.000000     319795.000000  319795.000000
# mean        4.396742       0.300386          0.775362       2.220904
# std         1.212208       0.716480          0.417344       1.534647
# min         0.000000       0.000000          0.000000       0.000000
# 25%         5.000000       0.000000          1.000000       1.000000
# 50%         5.000000       0.000000          1.000000       2.000000
# 75%         5.000000       0.000000          1.000000       4.000000
# max         5.000000       3.000000          1.000000       4.000000
#
#            SleepTime         Asthma  KidneyDisease     SkinCancer  \
# count  319795.000000  319795.000000  319795.000000  319795.000000
# mean        7.097075       0.134061       0.036833       0.093244
# std         1.436007       0.340718       0.188352       0.290775
# min         1.000000       0.000000       0.000000       0.000000
# 25%         6.000000       0.000000       0.000000       0.000000
# 50%         7.000000       0.000000       0.000000       0.000000
# 75%         8.000000       0.000000       0.000000       0.000000
# max        24.000000       1.000000       1.000000       1.000000
#
#              Outcome            Age
# count  319795.000000  319795.000000
# mean        0.085595      55.035498
# std         0.279766      18.829023
# min         0.000000      21.000000
# 25%         0.000000      42.000000
# 50%         0.000000      57.000000
# 75%         0.000000      67.000000
# max         1.000000      89.000000

# %%
df.groupby("Outcome").mean()
# Out:
#                BMI   Smoking  AlcoholDrinking    Stroke  PhysicalHealth  \
# Outcome
# 0        28.224658  0.396246         0.070569  0.026263        2.956416
# 1        29.401592  0.585869         0.041683  0.160340        7.808242
#
#          MentalHealth  DiffWalking       Sex      Race  Diabetic  \
# Outcome
# 0            3.828778     0.117577  0.464572  4.383815  0.263438
# 1            4.641764     0.366346  0.589596  4.534834  0.695101
#
#          PhysicalActivity  GenHealth  SleepTime    Asthma  KidneyDisease  \
# Outcome
# 0                0.788135   2.226098   7.093416  0.129741       0.028466
# 1                0.638914   2.165418   7.136156  0.180214       0.126219
#
#          SkinCancer        Age
# Outcome
# 0          0.084942  53.675862
# 1          0.181931  69.560297

# %%
X = df.drop("Outcome",axis=1)
Y = df["Outcome"]
print(X)
# Out:
#           BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  MentalHealth  \
# 0       16.60        1                0       0             3.0          30.0
# 1       20.34        0                0       1             0.0           0.0
# 2       26.58        1                0       0            20.0          30.0
# 3       24.21        0                0       0             0.0           0.0
# 4       23.71        0                0       0            28.0           0.0
# ...       ...      ...              ...     ...             ...           ...
# 319790  27.41        1                0       0             7.0           0.0
# 319791  29.84        1                0       0             0.0           0.0
# 319792  24.24        0                0       0             0.0           0.0
# 319793  32.81        0                0       0             0.0           0.0
# 319794  46.56        0                0       0             0.0           0.0
#
#         DiffWalking  Sex  Race  Diabetic  PhysicalActivity  GenHealth  \
# 0                 0    0     5         2                 1          4
# 1                 0    0     5         0                 1          4
# 2                 0    1     5         2                 1          1
# 3                 0    0     5         0                 0          2
# 4                 1    0     5         0                 1          4
# ...             ...  ...   ...       ...               ...        ...
# 319790            1    1     3         2                 0          1
# 319791            0    1     3         0                 1          4
# 319792            0    0     3         0                 1          2
# 319793            0    0     3         0                 0          2
# 319794            0    0     3         0                 1          2
#
#         SleepTime  Asthma  KidneyDisease  SkinCancer  Age
# 0             5.0       1              0           1   57
# 1             7.0       0              0           0   89
# 2             8.0       1              0           0   67
# 3             6.0       0              0           1   77
# 4             8.0       0              0           0   42
# ...           ...     ...            ...         ...  ...
# 319790        6.0       1              0           0   62
# 319791        5.0       1              0           0   37
# 319792        6.0       0              0           0   47
# 319793       12.0       0              0           0   27
# 319794        8.0       0              0           0   89
#
# [319795 rows x 17 columns]

# %%
print(Y)
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 319790    1
# 319791    0
# 319792    0
# 319793    0
# 319794    0
# Name: Outcome, Length: 319795, dtype: int64

# %%
scaler = StandardScaler()

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %%
standardized_data = scaler.transform(X)

# %%
print(standardized_data)
# Out:
# [[-1.84475016  1.19347355 -0.27031975 ... -0.19555439  3.11841916
#    0.1043339 ]
#  [-1.25633812 -0.83789038 -0.27031975 ... -0.19555439 -0.3206753
#    1.80384056]
#  [-0.27460254  1.19347355 -0.27031975 ... -0.19555439 -0.3206753
#    0.63542973]
#  ...
#  [-0.64275338 -0.83789038 -0.27031975 ... -0.19555439 -0.3206753
#   -0.42676194]
#  [ 0.70555975 -0.83789038 -0.27031975 ... -0.19555439 -0.3206753
#   -1.4889536 ]
#  [ 2.86883929 -0.83789038 -0.27031975 ... -0.19555439 -0.3206753
#    1.80384056]]

# %%
X = standardized_data

# %%
Y = df["Outcome"]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.2, stratify=Y, random_state=2
)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (319795, 17) (255836, 17) (63959, 17)

# %%
classifier = svm.SVC(kernel="linear")

# %%
classifier.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %%
X_train_prediction = classifier.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print("Accuracy score of the training data: {}".format(training_data_accuracy))
# Out:
# Accuracy score of the training data: 0.9144061039103175

# %%
X_test_prediction = classifier.predict(X_test)
testing_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print("Accuracy score of the testing data: {}".format(testing_data_accuracy))
# Out:
# Accuracy score of the testing data: 0.9143982864022264

# %%
input_data = (26.58, 1, 0, 0, 20.0, 30.0, 0, 1, 5, 2, 1, 1, 8.0, 1, 0, 0, 67)
input_np_array = np.asarray(input_data)
reshaped_input_data = input_np_array.reshape(1, -1)

# %%
standardized_data_input = scaler.transform(reshaped_input_data)
# Out:
# /home/veer/.local/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
prediction = classifier.predict(standardized_data_input)

# %%
if prediction[0] == 0:
    print(
        "The person with the given attribuites has a higher probability of not having any heart diseases"
    )
else:
    print(
        "The person with the given attribuites has a higher probability of having any heart diseases"
    )
# Out:
# The person with the given attribuites has a higher probability of not having any heart diseases
